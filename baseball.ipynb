# %%
import pandas as pd					# data manipulation using dataframes
import numpy as np					# data statistical analysis

import seaborn as sns				# Statistical data visualization
import matplotlib.pyplot as plt		# data visualisation
# %matplotlib inline

# %%
raw_df = pd.read_csv("Baseball.csv")

# %%
df = raw_df.copy()

# %%
df.shape
# Out:
# (30, 17)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'Blues' )
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values so we can proceed

# %%
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# No need to change the datatype they are appropriate so we can skip the step of data conversion Now directly jumps to Visualization

# %% [markdown]
# # EDA

# %%
import seaborn as sns
sns.regplot(x="R",y="W",data=df)
plt.show()
sns.histplot(x='R',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="AB",data=df)
plt.show()
sns.boxplot(y='R',data=df)
plt.show()

# %% [markdown]
# Outlier are present between 850 to 900.

# %%
sns.regplot(x="AB",y="W",data=df)
plt.show()
sns.histplot(x='AB',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="AB",data=df)
plt.show()
sns.boxplot(y='AB',data=df)
plt.show()

# %% [markdown]
# At balls is very weekly related to Wins With no outliers.

# %%
sns.regplot(x="H",y="W",data=df)
plt.show()
sns.histplot(x='H',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="H",data=df)
plt.show()
sns.boxplot(y='H',data=df)
plt.show()

# %% [markdown]
# Hits are also very weekly related to winning with no outliers

# %%
sns.regplot(x="2B",y="W",data=df)
plt.show()
sns.histplot(x='2B',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="2B",data=df)
plt.show()
sns.boxplot(y='2B',data=df)
plt.show()

# %% [markdown]
# Doubles are linearly related with Wins, with no outlier, and data is left-skewed.

# %%
sns.regplot(x="3B",y="W",data=df)
plt.show()
sns.histplot(x='3B',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="3B",data=df)
plt.show()
sns.boxplot(y='3B',data=df)
plt.show()

# %% [markdown]
# Triple has very weak negative correlations with win with no outlier and data is right-skewed

# %%
sns.regplot(x="HR",y="W",data=df)
plt.show()
sns.histplot(x='HR',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="HR",data=df)
plt.show()
sns.boxplot(y='HR',data=df)
plt.show()

# %% [markdown]
# The home run has a very low correlation with wins with no lot of outliers and data is right-skewed.

# %%
sns.regplot(x="BB",y="W",data=df)
plt.show()
sns.histplot(x='BB',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="BB",data=df)
plt.show()
sns.boxplot(y='BB',data=df)
plt.show()

# %% [markdown]
# Walk is lightly correlated to win with no outlier.

# %%
sns.regplot(x="SO",y="W",data=df)
plt.show()
sns.histplot(x='SO',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="SO",data=df)
plt.show()
sns.boxplot(y='SO',data=df)
plt.show()

# %% [markdown]
# Strikeout is not correlated to win with no outlier and the dataset is left-skewed.

# %%
sns.regplot(x="SB",y="W",data=df)
plt.show()
sns.histplot(x='SB',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="SB",data=df)
plt.show()
sns.boxplot(y='SB',data=df)
plt.show()

# %% [markdown]
# Stolen Bases is not correlated to win with no outlier.

# %%
sns.regplot(x="RA",y="W",data=df)
plt.show()
sns.histplot(x='RA',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="RA",data=df)
plt.show()
sns.boxplot(y='RA',data=df)
plt.show()

# %% [markdown]
# Runs Allowed is highly correlated to win with no outliers.

# %%
sns.regplot(x="ER",y="W",data=df)
plt.show()
sns.histplot(x='ER',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="ER",data=df)
plt.show()
sns.boxplot(y='ER',data=df)
plt.show()

# %% [markdown]
# Earned Runs is highly correlated to win with no outliers

# %%
sns.regplot(x="ERA",y="W",data=df)
plt.show()
sns.histplot(x='ERA',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="ERA",data=df)
plt.show()
sns.boxplot(y='ERA',data=df)
plt.show()

# %% [markdown]
# Earned Runs avarage is highly correlated to win with outlier above 5.0.

# %%
sns.regplot(x="CG",y="W",data=df)
plt.show()
sns.histplot(x='CG',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="CG",data=df)
plt.show()
sns.boxplot(y='CG',data=df)
plt.show()

# %% [markdown]
# CG is not correlated to win with no outliers and data is right-skewed.

# %%
sns.regplot(x="SHO",y="W",data=df)
plt.show()
sns.histplot(x='SHO',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="SHO",data=df)
plt.show()
sns.boxplot(y='SHO',data=df)
plt.show()

# %% [markdown]
# Shutouts are highly correlated to win with no outliers and data is right-skewed.

# %%
sns.regplot(x="SV",y="W",data=df)
plt.show()
sns.histplot(x='SV',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="SV",data=df)
plt.show()
sns.boxplot(y='SV',data=df)
plt.show()

# %% [markdown]
# Saves are lightly correlated to win with no outliers-skewed.

# %%
sns.regplot(x="E",y="W",data=df)
plt.show()
sns.histplot(x='E',data=df,kde=True)
plt.show()
plt.figure(figsize=(18,10))
ax=sns.countplot(x="E",data=df)
plt.show()
sns.boxplot(y='E',data=df)
plt.show()

# %% [markdown]
# Errors are not correlated to win, the data has outliers and data is right-skewed.

# %% [markdown]
# 1. The number of runs, home runs, doubles, Saves, Shutouts, and Walks are highly positively linearly correlated.
# 2. Stolen Bases, Runs Allowed, Earned Runs are highly negative linearly correlated.
# 3. The remaining features have less to no linear correlation with no of Wins

# %% [markdown]
# # SKEWNESS

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# There is skewness present in R,H,CG,SV and E.

# %%
skew=('R','H','CG','SV','E')
for col in skew:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO    0.565790
# SV     0.163057
# E      0.632916
# dtype: float64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %%
df_new=df.drop([5],axis=0)

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.388428
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %% [markdown]
# Now we can move forward.

# %% [markdown]
# # OUTLIERS

# %%
# to check all variables at once

df.hist( bins = 10, figsize = (10,10))
plt.show()

# %%
import seaborn as sns
collist=df_new.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data= df_new[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# There is very less outliers so we can proceed further.

# %% [markdown]
# # Correlation

# %%
# plotting heatmap
plt.figure(figsize=[19,10],facecolor='pink')
sns.heatmap(df_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# By Correlation we will find the relation between different column. RA and ER column are highly corelated. ERA,ER ,RA and W column are not corelated with each other.

# %%
plt.figure(figsize=(22,7))
df_new.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=18)
plt.ylabel('W',fontsize=18)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# W column is highly correlated with SV and less correlated with ERA.

# %% [markdown]
# # Scalling the data using Min-Max Scaler

# %%
### Define X&Y ###

x = df_new.iloc[:, 1:].values
y = df_new.iloc[:, 0].values

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Training and Testing the Model

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
def models(x_train, y_train):
    from sklearn.linear_model import LogisticRegression

    log = LogisticRegression(random_state = 0)
    log.fit(x_train, y_train)

    from sklearn.neighbors import KNeighborsClassifier
    knn = KNeighborsClassifier(n_neighbors = 5,metric = 'minkowski', p =2)
    knn.fit(x_train, y_train)

    from sklearn.svm import SVC
    svc_lin = SVC(kernel = 'linear', random_state = 0)
    svc_lin.fit(x_train, y_train)

    from sklearn.svm import SVC
    svc_rbf = SVC(kernel = 'rbf', random_state = 0)
    svc_rbf.fit(x_train, y_train)

    from sklearn.naive_bayes import GaussianNB
    gauss = GaussianNB()
    gauss.fit(x_train, y_train)

    from sklearn.tree import DecisionTreeClassifier
    tree = DecisionTreeClassifier(criterion = 'entropy', random_state =0)
    tree.fit(x_train,y_train)
    
    from sklearn.ensemble import RandomForestClassifier
    forest=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
    forest.fit(x_train,y_train)

    print('[0]Logistic Regression Training Accuracy:', log.score(x_train, y_train))
    print('[1]K Nearest Neighbor Training Accuracy:', knn.score(x_train, y_train))
    print('[2]Support Vector Machine (Linear Classifier) Training Accuracy:', svc_lin.score(x_train, y_train))
    print('[3]Support Vector Machine (RBF Classifier) Training Accuracy:', svc_rbf.score(x_train, y_train))
    print('[4]Gaussian Naive Bayes Training Accuracy:', gauss.score(x_train, y_train))
    print('[5]Decision Tree Classsifier Training Accuracy:', tree.score(x_train, y_train))
    print('[6]Random Forest Classifier Training Accuracy:', forest.score(x_train, y_train))

    return log, knn, svc_lin, svc_rbf, gauss, tree, forest

# %%
model = models(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7190a8f9c2fc> in <module>
# ----> 1 model = models(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# # Linear Regressor

# %%
maxAcc=0
MaxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    acc=r2_score(y_test,pred_test)
    if acc>maxAcc:
        maxAcc=acc
        MaxRs=i
print("Best Accuracy is",maxAcc,"on random state", MaxRs)
# Out:
# Best Accuracy is 0.9529920685351672 on random state 106

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=106)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Linear coefficients : {lr.coef_}")
print(f"Intercept : {lr.intercept_}")
# Out:
# Linear coefficients : [ 8.39578481e+01 -5.69965562e-02  4.55819075e+01 -6.19904415e-02
#   2.31282550e-02 -5.75527502e-02 -1.37437457e-02  3.91948473e-03
#  -4.22826722e-02  2.46921361e-02  4.19321464e-01 -8.17733361e+01
#   1.51995595e+00  1.55186223e-01  1.77449068e+01  3.77051267e+00]
# Intercept : -500.40966078114917

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9529920685351672

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 2.385135507406005
# MSE: 7.865993865115363
# RMSE: 2.804637920501569

# %%
sns.regplot(x=y_test,y=pred_test)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Random Forest Classifier

# %%
maxAcc=0
MaxRs=0
for i in range(1,200):
    forest=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=i)
    forest.fit(x_train,y_train)
    pred1=forest.predict(x_test)
    acc=r2_score(y_test,pred1)
    if acc>maxAcc:
        maxAcc=acc
        MaxRs=i
print("Best Accuracy is",maxAcc,"on random state", MaxRs)
# Out:
# Best Accuracy is 0.8037848605577689 on random state 101

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=101)
forest.fit(x_train,y_train)
pred1=forest.predict(x_test)
print(r2_score(y_test,pred1))
# Out:
# 0.8037848605577689

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred1))
print('MSE:', metrics.mean_squared_error(y_test, pred1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred1)))
# Out:
# MAE: 4.833333333333333
# MSE: 32.833333333333336
# RMSE: 5.730037812557028

# %%
sns.regplot(x=y_test,y=pred1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

maxAcc=0
MaxRs=0
for i in range(1,200):
    tree = DecisionTreeClassifier(criterion = 'entropy', random_state =i)
    tree.fit(x_train,y_train)
    pred2=tree.predict(x_test)
    acc=r2_score(y_test,pred2)
    if acc>maxAcc:
        maxAcc=acc
        MaxRs=i
print("Best Accuracy is",maxAcc,"on random state", MaxRs)
# Out:
# Best Accuracy is 0.7948207171314741 on random state 47

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred2))
print('MSE:', metrics.mean_squared_error(y_test, pred2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred2)))
# Out:
# MAE: 9.166666666666666
# MSE: 117.16666666666667
# RMSE: 10.824355254086345

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion = 'entropy', random_state =47)
tree.fit(x_train,y_train)
pred2=tree.predict(x_test)
print(r2_score(y_test,pred2))
# Out:
# 0.7948207171314741

# %%
sns.regplot(x=y_test,y=pred2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
maxAcc=0
MaxRs=0
for i in range(1,200):
    svc_lin = SVC(kernel = 'linear', random_state = i)
    svc_lin.fit(x_train, y_train)
    pred3=svc_lin.predict(x_test)
    acc=r2_score(y_test,pred3)
    if acc>maxAcc:
        maxAcc=acc
        MaxRs=i
print("Best Accuracy is",maxAcc,"on random state", MaxRs)
# Out:
# Best Accuracy is 0.3326693227091634 on random state 1

# %%
from sklearn.svm import SVC
svc_lin = SVC(kernel = 'linear', random_state = 1)
svc_lin.fit(x_train, y_train)
pred3=svc_lin.predict(x_test)
print(r2_score(y_test,pred3))
# Out:
# 0.3326693227091634

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred3))
print('MSE:', metrics.mean_squared_error(y_test, pred3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred3)))
# Out:
# MAE: 9.666666666666666
# MSE: 111.66666666666667
# RMSE: 10.567244989431572

# %%
sns.regplot(x=y_test,y=pred3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
maxAcc=0
MaxRs=0
for i in range(1,200):
    gauss = GaussianNB()
    gauss.fit(x_train, y_train)
    pred4=gauss.predict(x_test)
    acc=r2_score(y_test,pred4)
    if acc>maxAcc:
        maxAcc=acc
        MaxRs=i
print("Best Accuracy is",maxAcc,"on random state", MaxRs)
# Out:
# Best Accuracy is 0.1683266932270916 on random state 1

# %%
from sklearn.naive_bayes import GaussianNB
gauss = GaussianNB()
gauss.fit(x_train, y_train)
pred4=gauss.predict(x_test)
print(r2_score(y_test,pred4))
# Out:
# 0.1683266932270916

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred4))
print('MSE:', metrics.mean_squared_error(y_test, pred4))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred4)))
# Out:
# MAE: 10.833333333333334
# MSE: 139.16666666666666
# RMSE: 11.796892246124258

# %%
sns.regplot(x=y_test,y=pred4)
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     14.29
# Date:                Fri, 08 Apr 2022   Prob (F-statistic):           1.95e-05
# Time:                        15:42:47   Log-Likelihood:                -65.035
# No. Observations:                  29   AIC:                             164.1
# Df Residuals:                      12   BIC:                             187.3
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -549.5760    231.384     -2.375      0.035   -1053.718     -45.434
# x1            85.2055     26.688      3.193      0.008      27.056     143.355
# x2            -0.0418      0.040     -1.047      0.316      -0.129       0.045
# x3            40.0258     51.709      0.774      0.454     -72.639     152.690
# x4            -0.0959      0.074     -1.299      0.218      -0.257       0.065
# x5             0.0285      0.120      0.238      0.816      -0.233       0.290
# x6            -0.0430      0.067     -0.637      0.536      -0.190       0.104
# x7            -0.0252      0.023     -1.113      0.288      -0.075       0.024
# x8            -0.0022      0.011     -0.203      0.843      -0.026       0.022
# x9            -0.0194      0.041     -0.478      0.641      -0.108       0.069
# x10            0.1092      0.129      0.845      0.415      -0.172       0.391
# x11            0.2217      0.410      0.540      0.599      -0.672       1.116
# x12          -64.6686     55.924     -1.156      0.270    -186.517      57.180
# x13            2.5257      1.633      1.546      0.148      -1.033       6.084
# x14            0.2251      0.303      0.742      0.472      -0.436       0.886
# x15           24.9644      8.754      2.852      0.015       5.891      44.038
# x16            0.6424      6.868      0.094      0.927     -14.321      15.606
# ==============================================================================
# Omnibus:                        2.832   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.243   Jarque-Bera (JB):                2.433
# Skew:                          -0.688   Prob(JB):                        0.296
# Kurtosis:                       2.652   Cond. No.                     2.06e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Cross-Validation of the model:

# %%
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,5):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold{j} the cv score is {cv_mean} and accuracy for testing is { test_accuracy}")
    print("\n")
# Out:
# at cross fold2 the cv score is -1.4894439978418115 and accuracy for testing is 0.9529920685351672
#
#
# at cross fold3 the cv score is -1.7876259337238907 and accuracy for testing is 0.9529920685351672
#
#
# at cross fold4 the cv score is -0.2853482266247903 and accuracy for testing is 0.9529920685351672

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10,100],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 76.76005898164809

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 42.241782156312745

# %%
cv_score=cross_val_score(ls,x,y,cv=4)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 46.231981243192074

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=4)
rfc = rfscore.mean()
print('Cross Val Score:', rfc*100)
# Out:
# R2 Score: 62.008376494023935
# Cross Val Score: 52.64391180671198

# %% [markdown]
# # Conclusion

# %%
import pickle
filename='baseball.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 62.008376494023935

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","original"])

# %%
conclusion
# Out:
#                0      1      2      3      4      5
# Predicted  79.46  74.06  75.65  76.63  83.43  90.42
# original   79.46  74.06  75.65  76.63  83.43  90.42
